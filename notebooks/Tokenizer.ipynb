# %%
import sys
from pathlib import Path

sys.path.append("..")
from tokenizer import create_tokenizer

# %% [markdown]
# ### Create the Tokenizer

# %%
tknzr = create_tokenizer(
    tokenizer_kind="sentencepiece",
    model_path=Path("./models/en-de/wmt/shared"),
    vocab_size=37000,
    algorithm="bpe",
    sample_size=200000,
)

# %% [markdown]
# ### Train the tokenizer on the dataset
